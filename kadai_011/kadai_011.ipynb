# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# for文を使う
for value in array:
  print(value)

# さらに、while文を使う
i = 0
while i <= 8:
  print(array[i])
  i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
